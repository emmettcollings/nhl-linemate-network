# %%
# Author: Banafsheh Khazali, Emmett Collings
# Date: Oct 2, 2022

# %%
import networkx as nx  # make sure you installed networkx
import numpy as np
import pandas as pd

# %%
# Graph with 2 edges per pairing
# Read in data
df = pd.read_csv("../../data/defense/defensemen_edgelist_corsi.csv")

# Create a network of nodes which are players and the links are players that played together
# We create 2 graphs, one for each relationship direction and then compose them for our total graph
df = df.rename(columns={'corsi_influence_on_player2_stdDevs': 'weight'})
G0 = nx.Graph()
G0 = nx.from_pandas_edgelist(df, 'playerId1', 'playerId2', [
                             'weight'], create_using=nx.DiGraph)

df = df.rename(columns={'weight': 'notweight',
               'corsi_influence_on_player1_stdDevs': 'weight'})
G1 = nx.Graph()
G1 = nx.from_pandas_edgelist(
    df, 'playerId2', 'playerId1', edge_attr='weight', create_using=nx.DiGraph)

G = nx.compose(G0, G1)

# Add player names to nodes
players_df = pd.read_csv(
    "../../data/defense/aggregate_defensemen.csv", index_col='playerId', header=0)
player_names = dict.fromkeys(G.nodes)
for player in G.nodes:
    player_name = players_df.loc[[player]]["playerName"].values[0]
    player_names[player] = player_name

nx.set_node_attributes(G, player_names, "playerName")

# output a gephi file for ez visualization
nx.write_gexf(G, 'defense.gexf')

# %% [markdown]
# # Basic Statistics

# %%
# Number of nodes and edges
num_nodes = G.number_of_nodes()
num_edges = G.number_of_edges()
print("Number of nodes: ", num_nodes)
print("Number of edges: ", num_edges)

# Average outgoing link weight. This determines which players had the greatest effect on their linemates
# Do total out degree as well
out_degrees = G.out_degree(weight="weight")
for player_out_degree in out_degrees:
    player_id = player_out_degree[0]
    avg_out_weight = player_out_degree[1] / G.out_degree(player_id)
    players_df.loc[player_id, "average_corsi_influence"] = avg_out_weight
    players_df.loc[player_id, "total_out_influence"] = player_out_degree[1]

output_file = '../../data/defense/aggregate_defensemen.csv'
players_df.to_csv(output_file)

# Outgoing link weight correlations
print(players_df.corr(numeric_only=True))
players_df.corr(numeric_only=True, method='spearman').to_csv(
    "../../data/defense/correlations.csv")
# Out:
# Number of nodes:  550
# Number of edges:  4452
#                                   games_played   icetime  \
# games_played                          1.000000  0.993911
# icetime                               0.993911  1.000000
# onIce_corsiPercentage                 0.212017  0.211433
# offIce_corsiPercentage                0.119513  0.111242
# timeOnBench                           0.998183  0.985843
# on_off_corsi_diff                     0.135734  0.141060
# OnIce_F_goals_per60                   0.174954  0.176515
# OnIce_A_goals_per60                  -0.094652 -0.089327
# I_F_dZoneGiveaways_per60             -0.010803 -0.007322
# I_F_giveaways_per60                   0.023309  0.028775
# average_TOI                           0.628646  0.658497
# I_F_hits_per60                       -0.127099 -0.145075
# I_F_takeaways_per60                   0.143587  0.156784
# I_F_points_per60                      0.148772  0.156613
# shotsBlockedByPlayer_per60            0.030749  0.020186
# I_F_oZoneShiftStarts_per60           -0.062210 -0.060464
# I_F_dZoneShiftStarts_per60            0.237393  0.234340
# I_F_neutralZoneShiftStarts_per60      0.191716  0.192782
# I_F_flyShiftStarts_per60             -0.454402 -0.479365
# I_F_primaryAssists_per60              0.135569  0.138540
# I_F_secondaryAssists_per60            0.037243  0.042895
# I_F_goals_per60                       0.098508  0.103135
# average_corsi_influence               0.133208  0.138285
# total_out_influence                   0.137653  0.153193
#
#                                   onIce_corsiPercentage  \
# games_played                                   0.212017
# icetime                                        0.211433
# onIce_corsiPercentage                          1.000000
# offIce_corsiPercentage                         0.404651
# timeOnBench                                    0.211123
# on_off_corsi_diff                              0.754369
# OnIce_F_goals_per60                            0.279053
# OnIce_A_goals_per60                           -0.092700
# I_F_dZoneGiveaways_per60                      -0.009611
# I_F_giveaways_per60                            0.031984
# average_TOI                                    0.228512
# I_F_hits_per60                                -0.150663
# I_F_takeaways_per60                            0.111335
# I_F_points_per60                               0.270240
# shotsBlockedByPlayer_per60                    -0.301358
# I_F_oZoneShiftStarts_per60                     0.217679
# I_F_dZoneShiftStarts_per60                    -0.179820
# I_F_neutralZoneShiftStarts_per60              -0.058654
# I_F_flyShiftStarts_per60                      -0.113385
# I_F_primaryAssists_per60                       0.271595
# I_F_secondaryAssists_per60                     0.109213
# I_F_goals_per60                                0.095819
# average_corsi_influence                        0.761708
# total_out_influence                            0.598086
#
#                                   offIce_corsiPercentage  timeOnBench  \
# games_played                                    0.119513     0.998183
# icetime                                         0.111242     0.985843
# onIce_corsiPercentage                           0.404651     0.211123
# offIce_corsiPercentage                          1.000000     0.122300
# timeOnBench                                     0.122300     1.000000
# on_off_corsi_diff                              -0.295048     0.132798
# OnIce_F_goals_per60                             0.083199     0.173397
# OnIce_A_goals_per60                            -0.010626    -0.096704
# I_F_dZoneGiveaways_per60                       -0.057165    -0.011679
# I_F_giveaways_per60                            -0.042453     0.021434
# average_TOI                                     0.090949     0.610772
# I_F_hits_per60                                  0.030309    -0.117447
# I_F_takeaways_per60                            -0.025313     0.137517
# I_F_points_per60                                0.001300     0.144032
# shotsBlockedByPlayer_per60                     -0.042766     0.035991
# I_F_oZoneShiftStarts_per60                      0.196529    -0.063864
# I_F_dZoneShiftStarts_per60                     -0.168010     0.236813
# I_F_neutralZoneShiftStarts_per60                0.046359     0.188362
# I_F_flyShiftStarts_per60                       -0.037465    -0.438335
# I_F_primaryAssists_per60                        0.058451     0.133513
# I_F_secondaryAssists_per60                      0.020306     0.034227
# I_F_goals_per60                                -0.086920     0.095444
# average_corsi_influence                         0.242511     0.128360
# total_out_influence                             0.142099     0.126254
#
#                                   on_off_corsi_diff  OnIce_F_goals_per60  \
# games_played                               0.135734             0.174954
# icetime                                    0.141060             0.176515
# onIce_corsiPercentage                      0.754369             0.279053
# offIce_corsiPercentage                    -0.295048             0.083199
# timeOnBench                                0.132798             0.173397
# on_off_corsi_diff                          1.000000             0.231844
# OnIce_F_goals_per60                        0.231844             1.000000
# OnIce_A_goals_per60                       -0.089230            -0.083922
# I_F_dZoneGiveaways_per60                   0.030993            -0.085177
# I_F_giveaways_per60                        0.063893            -0.088523
# average_TOI                                0.173473             0.215929
# I_F_hits_per60                            -0.179177            -0.129057
# I_F_takeaways_per60                        0.134499             0.039889
# I_F_points_per60                           0.281426             0.619320
# shotsBlockedByPlayer_per60                -0.284173             0.017664
# I_F_oZoneShiftStarts_per60                 0.086363            -0.063356
# I_F_dZoneShiftStarts_per60                -0.067279             0.003447
# I_F_neutralZoneShiftStarts_per60          -0.094564            -0.074563
# I_F_flyShiftStarts_per60                  -0.091576            -0.075256
# I_F_primaryAssists_per60                   0.241816             0.370436
# I_F_secondaryAssists_per60                 0.099534             0.365725
# I_F_goals_per60                            0.162511             0.330670
# average_corsi_influence                    0.648421             0.227980
# total_out_influence                        0.552660             0.222356
#
#                                   OnIce_A_goals_per60  \
# games_played                                -0.094652
# icetime                                     -0.089327
# onIce_corsiPercentage                       -0.092700
# offIce_corsiPercentage                      -0.010626
# timeOnBench                                 -0.096704
# on_off_corsi_diff                           -0.089230
# OnIce_F_goals_per60                         -0.083922
# OnIce_A_goals_per60                          1.000000
# I_F_dZoneGiveaways_per60                    -0.053817
# I_F_giveaways_per60                         -0.089012
# average_TOI                                 -0.215717
# I_F_hits_per60                               0.002595
# I_F_takeaways_per60                         -0.059846
# I_F_points_per60                            -0.044324
# shotsBlockedByPlayer_per60                  -0.026548
# I_F_oZoneShiftStarts_per60                  -0.125401
# I_F_dZoneShiftStarts_per60                  -0.089646
# I_F_neutralZoneShiftStarts_per60            -0.177513
# I_F_flyShiftStarts_per60                     0.319686
# I_F_primaryAssists_per60                    -0.046975
# I_F_secondaryAssists_per60                  -0.076450
# I_F_goals_per60                              0.066074
# average_corsi_influence                     -0.186578
# total_out_influence                         -0.139243
#
#                                   I_F_dZoneGiveaways_per60  \
# games_played                                     -0.010803
# icetime                                          -0.007322
# onIce_corsiPercentage                            -0.009611
# offIce_corsiPercentage                           -0.057165
# timeOnBench                                      -0.011679
# on_off_corsi_diff                                 0.030993
# OnIce_F_goals_per60                              -0.085177
# OnIce_A_goals_per60                              -0.053817
# I_F_dZoneGiveaways_per60                          1.000000
# I_F_giveaways_per60                               0.937097
# average_TOI                                      -0.036344
# I_F_hits_per60                                    0.059409
# I_F_takeaways_per60                               0.132781
# I_F_points_per60                                 -0.036137
# shotsBlockedByPlayer_per60                        0.039227
# I_F_oZoneShiftStarts_per60                       -0.031304
# I_F_dZoneShiftStarts_per60                       -0.024692
# I_F_neutralZoneShiftStarts_per60                 -0.099703
# I_F_flyShiftStarts_per60                          0.051706
# I_F_primaryAssists_per60                          0.024475
# I_F_secondaryAssists_per60                       -0.022301
# I_F_goals_per60                                  -0.066882
# average_corsi_influence                          -0.082807
# total_out_influence                               0.085107
#
#                                   I_F_giveaways_per60  ...  \
# games_played                                 0.023309  ...
# icetime                                      0.028775  ...
# onIce_corsiPercentage                        0.031984  ...
# offIce_corsiPercentage                      -0.042453  ...
# timeOnBench                                  0.021434  ...
# on_off_corsi_diff                            0.063893  ...
# OnIce_F_goals_per60                         -0.088523  ...
# OnIce_A_goals_per60                         -0.089012  ...
# I_F_dZoneGiveaways_per60                     0.937097  ...
# I_F_giveaways_per60                          1.000000  ...
# average_TOI                                  0.013025  ...
# I_F_hits_per60                               0.017941  ...
# I_F_takeaways_per60                          0.219190  ...
# I_F_points_per60                            -0.040744  ...
# shotsBlockedByPlayer_per60                   0.010121  ...
# I_F_oZoneShiftStarts_per60                  -0.034423  ...
# I_F_dZoneShiftStarts_per60                  -0.035864  ...
# I_F_neutralZoneShiftStarts_per60            -0.124226  ...
# I_F_flyShiftStarts_per60                     0.015589  ...
# I_F_primaryAssists_per60                     0.012013  ...
# I_F_secondaryAssists_per60                  -0.030565  ...
# I_F_goals_per60                             -0.051545  ...
# average_corsi_influence                     -0.035369  ...
# total_out_influence                          0.147507  ...
#
#                                   shotsBlockedByPlayer_per60  \
# games_played                                        0.030749
# icetime                                             0.020186
# onIce_corsiPercentage                              -0.301358
# offIce_corsiPercentage                             -0.042766
# timeOnBench                                         0.035991
# on_off_corsi_diff                                  -0.284173
# OnIce_F_goals_per60                                 0.017664
# OnIce_A_goals_per60                                -0.026548
# I_F_dZoneGiveaways_per60                            0.039227
# I_F_giveaways_per60                                 0.010121
# average_TOI                                        -0.002999
# I_F_hits_per60                                      0.065849
# I_F_takeaways_per60                                -0.019212
# I_F_points_per60                                   -0.031072
# shotsBlockedByPlayer_per60                          1.000000
# I_F_oZoneShiftStarts_per60                         -0.083807
# I_F_dZoneShiftStarts_per60                          0.085965
# I_F_neutralZoneShiftStarts_per60                   -0.045472
# I_F_flyShiftStarts_per60                            0.045441
# I_F_primaryAssists_per60                           -0.096826
# I_F_secondaryAssists_per60                          0.059612
# I_F_goals_per60                                    -0.039096
# average_corsi_influence                            -0.281885
# total_out_influence                                -0.300287
#
#                                   I_F_oZoneShiftStarts_per60  \
# games_played                                       -0.062210
# icetime                                            -0.060464
# onIce_corsiPercentage                               0.217679
# offIce_corsiPercentage                              0.196529
# timeOnBench                                        -0.063864
# on_off_corsi_diff                                   0.086363
# OnIce_F_goals_per60                                -0.063356
# OnIce_A_goals_per60                                -0.125401
# I_F_dZoneGiveaways_per60                           -0.031304
# I_F_giveaways_per60                                -0.034423
# average_TOI                                        -0.104883
# I_F_hits_per60                                     -0.055054
# I_F_takeaways_per60                                 0.006175
# I_F_points_per60                                   -0.076553
# shotsBlockedByPlayer_per60                         -0.083807
# I_F_oZoneShiftStarts_per60                          1.000000
# I_F_dZoneShiftStarts_per60                         -0.196443
# I_F_neutralZoneShiftStarts_per60                    0.099934
# I_F_flyShiftStarts_per60                           -0.141961
# I_F_primaryAssists_per60                           -0.089716
# I_F_secondaryAssists_per60                         -0.035938
# I_F_goals_per60                                    -0.006821
# average_corsi_influence                             0.315964
# total_out_influence                                 0.232682
#
#                                   I_F_dZoneShiftStarts_per60  \
# games_played                                        0.237393
# icetime                                             0.234340
# onIce_corsiPercentage                              -0.179820
# offIce_corsiPercentage                             -0.168010
# timeOnBench                                         0.236813
# on_off_corsi_diff                                  -0.067279
# OnIce_F_goals_per60                                 0.003447
# OnIce_A_goals_per60                                -0.089646
# I_F_dZoneGiveaways_per60                           -0.024692
# I_F_giveaways_per60                                -0.035864
# average_TOI                                         0.224672
# I_F_hits_per60                                      0.071513
# I_F_takeaways_per60                                 0.099781
# I_F_points_per60                                    0.024014
# shotsBlockedByPlayer_per60                          0.085965
# I_F_oZoneShiftStarts_per60                         -0.196443
# I_F_dZoneShiftStarts_per60                          1.000000
# I_F_neutralZoneShiftStarts_per60                    0.290615
# I_F_flyShiftStarts_per60                           -0.328639
# I_F_primaryAssists_per60                           -0.104114
# I_F_secondaryAssists_per60                          0.003836
# I_F_goals_per60                                     0.152491
# average_corsi_influence                            -0.152527
# total_out_influence                                -0.166967
#
#                                   I_F_neutralZoneShiftStarts_per60  \
# games_played                                              0.191716
# icetime                                                   0.192782
# onIce_corsiPercentage                                    -0.058654
# offIce_corsiPercentage                                    0.046359
# timeOnBench                                               0.188362
# on_off_corsi_diff                                        -0.094564
# OnIce_F_goals_per60                                      -0.074563
# OnIce_A_goals_per60                                      -0.177513
# I_F_dZoneGiveaways_per60                                 -0.099703
# I_F_giveaways_per60                                      -0.124226
# average_TOI                                               0.155166
# I_F_hits_per60                                            0.065321
# I_F_takeaways_per60                                      -0.069487
# I_F_points_per60                                         -0.019212
# shotsBlockedByPlayer_per60                               -0.045472
# I_F_oZoneShiftStarts_per60                                0.099934
# I_F_dZoneShiftStarts_per60                                0.290615
# I_F_neutralZoneShiftStarts_per60                          1.000000
# I_F_flyShiftStarts_per60                                 -0.432354
# I_F_primaryAssists_per60                                 -0.059085
# I_F_secondaryAssists_per60                               -0.042849
# I_F_goals_per60                                           0.082858
# average_corsi_influence                                   0.020863
# total_out_influence                                      -0.055359
#
#                                   I_F_flyShiftStarts_per60  \
# games_played                                     -0.454402
# icetime                                          -0.479365
# onIce_corsiPercentage                            -0.113385
# offIce_corsiPercentage                           -0.037465
# timeOnBench                                      -0.438335
# on_off_corsi_diff                                -0.091576
# OnIce_F_goals_per60                              -0.075256
# OnIce_A_goals_per60                               0.319686
# I_F_dZoneGiveaways_per60                          0.051706
# I_F_giveaways_per60                               0.015589
# average_TOI                                      -0.670376
# I_F_hits_per60                                    0.171543
# I_F_takeaways_per60                              -0.165445
# I_F_points_per60                                 -0.063072
# shotsBlockedByPlayer_per60                        0.045441
# I_F_oZoneShiftStarts_per60                       -0.141961
# I_F_dZoneShiftStarts_per60                       -0.328639
# I_F_neutralZoneShiftStarts_per60                 -0.432354
# I_F_flyShiftStarts_per60                          1.000000
# I_F_primaryAssists_per60                          0.010322
# I_F_secondaryAssists_per60                       -0.026174
# I_F_goals_per60                                  -0.099624
# average_corsi_influence                          -0.096774
# total_out_influence                              -0.140437
#
#                                   I_F_primaryAssists_per60  \
# games_played                                      0.135569
# icetime                                           0.138540
# onIce_corsiPercentage                             0.271595
# offIce_corsiPercentage                            0.058451
# timeOnBench                                       0.133513
# on_off_corsi_diff                                 0.241816
# OnIce_F_goals_per60                               0.370436
# OnIce_A_goals_per60                              -0.046975
# I_F_dZoneGiveaways_per60                          0.024475
# I_F_giveaways_per60                               0.012013
# average_TOI                                       0.157171
# I_F_hits_per60                                   -0.151088
# I_F_takeaways_per60                               0.058082
# I_F_points_per60                                  0.532558
# shotsBlockedByPlayer_per60                       -0.096826
# I_F_oZoneShiftStarts_per60                       -0.089716
# I_F_dZoneShiftStarts_per60                       -0.104114
# I_F_neutralZoneShiftStarts_per60                 -0.059085
# I_F_flyShiftStarts_per60                          0.010322
# I_F_primaryAssists_per60                          1.000000
# I_F_secondaryAssists_per60                       -0.016201
# I_F_goals_per60                                   0.009004
# average_corsi_influence                           0.240969
# total_out_influence                               0.287041
#
#                                   I_F_secondaryAssists_per60  I_F_goals_per60  \
# games_played                                        0.037243         0.098508
# icetime                                             0.042895         0.103135
# onIce_corsiPercentage                               0.109213         0.095819
# offIce_corsiPercentage                              0.020306        -0.086920
# timeOnBench                                         0.034227         0.095444
# on_off_corsi_diff                                   0.099534         0.162511
# OnIce_F_goals_per60                                 0.365725         0.330670
# OnIce_A_goals_per60                                -0.076450         0.066074
# I_F_dZoneGiveaways_per60                           -0.022301        -0.066882
# I_F_giveaways_per60                                -0.030565        -0.051545
# average_TOI                                         0.025512         0.096016
# I_F_hits_per60                                     -0.114561        -0.017232
# I_F_takeaways_per60                                -0.068296         0.005908
# I_F_points_per60                                    0.668180         0.498400
# shotsBlockedByPlayer_per60                          0.059612        -0.039096
# I_F_oZoneShiftStarts_per60                         -0.035938        -0.006821
# I_F_dZoneShiftStarts_per60                          0.003836         0.152491
# I_F_neutralZoneShiftStarts_per60                   -0.042849         0.082858
# I_F_flyShiftStarts_per60                           -0.026174        -0.099624
# I_F_primaryAssists_per60                           -0.016201         0.009004
# I_F_secondaryAssists_per60                          1.000000        -0.021396
# I_F_goals_per60                                    -0.021396         1.000000
# average_corsi_influence                             0.138385         0.175682
# total_out_influence                                 0.170068         0.190186
#
#                                   average_corsi_influence  total_out_influence
# games_played                                     0.133208             0.137653
# icetime                                          0.138285             0.153193
# onIce_corsiPercentage                            0.761708             0.598086
# offIce_corsiPercentage                           0.242511             0.142099
# timeOnBench                                      0.128360             0.126254
# on_off_corsi_diff                                0.648421             0.552660
# OnIce_F_goals_per60                              0.227980             0.222356
# OnIce_A_goals_per60                             -0.186578            -0.139243
# I_F_dZoneGiveaways_per60                        -0.082807             0.085107
# I_F_giveaways_per60                             -0.035369             0.147507
# average_TOI                                      0.080763             0.128954
# I_F_hits_per60                                  -0.184901            -0.188643
# I_F_takeaways_per60                              0.192904             0.276545
# I_F_points_per60                                 0.269214             0.315379
# shotsBlockedByPlayer_per60                      -0.281885            -0.300287
# I_F_oZoneShiftStarts_per60                       0.315964             0.232682
# I_F_dZoneShiftStarts_per60                      -0.152527            -0.166967
# I_F_neutralZoneShiftStarts_per60                 0.020863            -0.055359
# I_F_flyShiftStarts_per60                        -0.096774            -0.140437
# I_F_primaryAssists_per60                         0.240969             0.287041
# I_F_secondaryAssists_per60                       0.138385             0.170068
# I_F_goals_per60                                  0.175682             0.190186
# average_corsi_influence                          1.000000             0.696428
# total_out_influence                              0.696428             1.000000
#
# [24 rows x 24 columns]

# %%
import matplotlib.pyplot as plt
# Chart some stats vs avg corsi influence
fig, axs = plt.subplots(2, 2)
fig.set_size_inches(8, 8)
axs[0, 0].scatter(players_df['average_corsi_influence'],
                  players_df['onIce_corsiPercentage'])
axs[0, 0].set_title("On Ice Corsi Percentage")
axs[0, 1].scatter(players_df['average_corsi_influence'],
                  players_df['I_F_takeaways_per60'])
axs[0, 1].set_title("Takeaways per 60")
axs[1, 0].scatter(players_df['average_corsi_influence'],
                  players_df['I_F_hits_per60'])
axs[1, 0].set_title("Hits per 60")
axs[1, 1].scatter(players_df['average_corsi_influence'],
                  players_df['average_TOI'])
axs[1, 1].set_title("Average Time On Ice")
plt.show()

# %%
# Chart some stats vs total out degree
fig, axs = plt.subplots(2, 2)
fig.set_size_inches(8, 8)
axs[0, 0].scatter(players_df['total_out_influence'],
                  players_df['onIce_corsiPercentage'])
axs[0, 0].set_title("On Ice Corsi Percentage")
axs[0, 1].scatter(players_df['total_out_influence'],
                  players_df['I_F_takeaways_per60'])
axs[0, 1].set_title("Takeaways per 60")
axs[1, 0].scatter(players_df['total_out_influence'],
                  players_df['I_F_hits_per60'])
axs[1, 0].set_title("Hits per 60")
axs[1, 1].scatter(players_df['total_out_influence'], players_df['average_TOI'])
axs[1, 1].set_title("Average Time On Ice")
plt.show()

# %%
# Average influence vs total influence
fig = plt.subplot()
fig.scatter(players_df["total_out_influence"],
            players_df["average_corsi_influence"])
plt.xlabel("Total Out Degree")
plt.ylabel("Average Out Weight")
plt.show()

# %%
# Number of connected components
is_strongly_connected = nx.is_strongly_connected(G)
print("Is graph strongly connected? ", is_strongly_connected)
num_strongly_connected_components = nx.number_strongly_connected_components(G)
print("Number of strongly connected components: ",
      num_strongly_connected_components)
# Out:
# Is graph strongly connected?  False
# Number of strongly connected components:  2

# %%
# Path length
for C in (G.subgraph(c).copy() for c in nx.weakly_connected_components(G)):
    print(nx.average_shortest_path_length(C))
# Out:
# 3.5132974819519878
# 1.0

# %%
# Degree distribution
import matplotlib.pyplot as plt
degree_sequence = sorted((d for n, d in G.degree()), reverse=True)
dmax = max(degree_sequence)

fig = plt.figure("Degree of a random graph", figsize=(8, 8))
# Create a gridspec for adding subplots of different sizes
axgrid = fig.add_gridspec(5, 4)

ax0 = fig.add_subplot(axgrid[0:3, :])
Gcc = G.subgraph(
    sorted(nx.strongly_connected_components(G), key=len, reverse=True)[0])
pos = nx.spring_layout(Gcc, seed=10396953)
nx.draw_networkx_nodes(Gcc, pos, ax=ax0, node_size=20)
nx.draw_networkx_edges(Gcc, pos, ax=ax0, alpha=0.4)
ax0.set_title("Strongly connected components of G")
ax0.set_axis_off()

ax1 = fig.add_subplot(axgrid[3:, :2])
ax1.plot(degree_sequence, "b-", marker="o")
ax1.set_title("Degree Rank Plot")
ax1.set_ylabel("Degree")
ax1.set_xlabel("Rank")

ax2 = fig.add_subplot(axgrid[3:, 2:])
ax2.bar(*np.unique(degree_sequence, return_counts=True))
ax2.set_title("Degree histogram")
ax2.set_xlabel("Degree")
ax2.set_ylabel("# of Nodes")

fig.tight_layout()
plt.show()

# %%
# Clustering coefficient
clustering_coefficients = nx.clustering(G)
# print("Clustering coefficient: ", clustering_coefficients)
average_clustering = nx.average_clustering(G)
print("Average clustering coefficient: ", average_clustering)
# Out:
# Average clustering coefficient:  0.26636734680272417

# %%
print(nx.is_weakly_connected(G))
# Out:
# False

# %% [markdown]
# # Centrality Measures

# %%
# Degree centrality
degree_centrality = nx.degree_centrality(G)
# print("Degree centrality: ", degree_centrality)
in_degree_centrality = nx.in_degree_centrality(G)
# print("In degree centrality: ", in_degree_centrality)
out_degree_centrality = nx.out_degree_centrality(G)
# print("Out degree centrality: ", out_degree_centrality)

# %%
# Plot the network
from matplotlib.pyplot import figure
figure(figsize=(10, 8))
nx.draw_spring(G, node_size=10)

# %%
# number of edges
G.number_of_edges()
# Out:
# 4452

# %%
# number of nodes
G.number_of_nodes()
# Out:
# 550

# %%
# basic analysis
N = len(G)
L = G.size()
degrees = [G.degree(node) for node in G]
kmin = min(degrees)
kmax = max(degrees)

# %%
print("Number of nodes: ", N)
print("Number of edges: ", L)
print()
print("Average degree: ", 2*L/N)
print("Average degree (alternate calculation)", np.mean(degrees))
print()
print("Minimum degree: ", kmin)
print("Maximum degree: ", kmax)
# Out:
# Number of nodes:  550
# Number of edges:  4452
#
# Average degree:  16.189090909090908
# Average degree (alternate calculation) 16.189090909090908
#
# Minimum degree:  2
# Maximum degree:  56

# %%
# Get 10 logarithmically spaced bins between kmin and kmax
bin_edges = np.logspace(np.log10(kmin), np.log10(kmax), num=10)

# histogram the data into these bins
density, _ = np.histogram(degrees, bins=bin_edges, density=True)

# %%
fig = plt.figure(figsize=(6, 4))

# "x" should be midpoint (IN LOG SPACE) of each bin
log_be = np.log10(bin_edges)
x = 10**((log_be[1:] + log_be[:-1])/2)

plt.loglog(x, density, marker='o', linestyle='none')
plt.xlabel(r"degree $k$", fontsize=16)
plt.ylabel(r"$P(k)$", fontsize=16)

# remove right and top boundaries because they're ugly
ax = plt.gca()
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.yaxis.set_ticks_position('left')
ax.xaxis.set_ticks_position('bottom')

# Show the plot
plt.show()

# %%
# Get 20 logarithmically spaced bins between kmin and kmax
bin_edges = np.linspace(kmin, 10, num=10)

# histogram the data into these bins
density, _ = np.histogram(degrees, bins=bin_edges, density=True)

# %%
fig = plt.figure(figsize=(8, 6))

# "x" should be midpoint (IN LOG SPACE) of each bin
log_be = np.log10(bin_edges)
x = 10**((log_be[1:] + log_be[:-1])/2)

plt.plot(x, density, marker='o', linestyle='none')
plt.xlabel(r"degree $k$", fontsize=16)
plt.ylabel(r"$P(k)$", fontsize=16)

# remove right and top boundaries because they're ugly
ax = plt.gca()
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.yaxis.set_ticks_position('left')
ax.xaxis.set_ticks_position('bottom')

# Show the plot
plt.show()

# %%
print(nx.info(G))
# Out:
# DiGraph with 550 nodes and 4452 edges
# /tmp/ipykernel_4941/2606185536.py:1: DeprecationWarning: info is deprecated and will be removed in version 3.0.
#
#   print(nx.info(G))

# %%
hist = nx.degree_histogram(G)
plt.figure(figsize=(9, 3))
plt.plot(hist, marker='.')
plt.xlim((0, 50))
plt.show()

# %%
def all_networks(g, start, end):
    def plotpath(g, path):
        h = nx.subgraph(g, path)
        nx.draw(h, pos=pos, node_color='r', edge_color='r',
                node_size=100, aplha=0.7, width=2)

    paths = nx.all_shortest_paths(g, source=start, target=end)
    paths = [i for i in paths]
    h = nx.subgraph(g, sum([i for i in paths], []))
    labels = nx.get_node_attributes(h, 'label')
    i = nx.subgraph(g, sum([nx.neighbors(g, i) for i in h.nodes()], []))
    pos = nx.fruchterman_reingold_layout(i)

    plt.figure(figsize=(9, 6))
    nx.draw(i, pos=pos, node_color='b',
            edge_color='b', node_size=50, alpha=0.5)
    [plotpath(g, i) for i in paths]
    nx.draw_networkx_labels(i, pos=pos, labels=labels, font_size=10)
    plt.show()

# %%
nx.draw(G, pos=nx.spring_layout(G), node_size=0.01, width=0.1)

# %%
fig, ax = plt.subplots(figsize=(15, 8))

nx.draw_spring(G, node_color='bisque', with_labels=True,
               node_size=40, font_size=4, alpha=0.5)
